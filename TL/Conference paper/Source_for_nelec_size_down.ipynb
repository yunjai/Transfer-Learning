# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import time
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential, load_model

# %%
dhw_merge = pd.read_csv('dhw_merge.csv')
elec_merge  = pd.read_csv('elec_merge.csv')
n_elec_merge = pd.read_csv('n_elec_merge.csv')

dhw_merge = dhw_merge.drop(['YEAR'], axis=1)
elec_merge = elec_merge.drop(['YEAR'], axis=1)
n_elec_merge = n_elec_merge.drop(['YEAR'], axis=1)

# %% [markdown]
# ##  For Scaling

# %%
dhw_X = dhw_merge.drop(['DHW'], axis=1)
dhw_Y = dhw_merge[['DHW']]

scaler_dhw = MinMaxScaler()
scaler_dhw.fit(dhw_X)
scaled_dhw_X = scaler_dhw.transform(dhw_X)

new_dhw_X = pd.DataFrame(scaled_dhw_X, index=dhw_X.index, columns=dhw_X.columns)
new_dhw = pd.concat([new_dhw_X, dhw_Y], axis=1)

# %%
elec_X = elec_merge.drop(['ELEC'], axis=1)
elec_Y = elec_merge[['ELEC']]

scaler_elec = MinMaxScaler()
scaler_elec.fit(elec_X)
scaled_elec_X = scaler_elec.transform(elec_X)

new_elec_X = pd.DataFrame(scaled_elec_X, index=elec_X.index, columns=elec_X.columns)
new_elec = pd.concat([new_elec_X, elec_Y], axis=1)

# %%
n_elec_X = n_elec_merge.drop(['n_elec'], axis=1)
n_elec_Y = n_elec_merge[['n_elec']]

scaler_n_elec = MinMaxScaler()
scaler_n_elec.fit(n_elec_X)
scaled_n_elec_X = scaler_n_elec.transform(n_elec_X)

new_n_elec_X = pd.DataFrame(scaled_n_elec_X, index=n_elec_X.index, columns=n_elec_X.columns)
new_n_elec = pd.concat([new_n_elec_X, n_elec_Y], axis=1)

new_n_elec = new_n_elec.iloc[:4724]

# %%
input_dhw = new_dhw.iloc[:-1,]
target_dhw = new_dhw[['DHW']].iloc[1:]

trainX_dhw, testX_dhw, trainY_dhw, testY_dhw = train_test_split(input_dhw,target_dhw,test_size=0.3,shuffle=False,random_state=0)

# %%
input_elec = new_elec.iloc[:-1,]
target_elec = new_elec[['ELEC']].iloc[1:]

trainX_elec, testX_elec, trainY_elec, testY_elec = train_test_split(input_elec,target_elec,test_size=0.3,shuffle=False,random_state=0)

# %%
input = new_n_elec.iloc[:-1,]
target = new_n_elec[['n_elec']].iloc[1:]

trainX_n_elec, testX_n_elec, trainY_n_elec, testY_n_elec = train_test_split(input,target,test_size=0.3,shuffle=False,random_state=0)

# %%
def buildDataSet(input, target, seqLength):
    xdata = []
    ydata = []
    for i in range(len(input) - seqLength):
        tx = input.iloc[i:i+seqLength]
        ty = target.iloc[i+seqLength-1]
        xdata.append(tx)
        ydata.append(ty)
    return np.array(xdata), np.array(ydata)

# %%
trainx_dhw, trainy_dhw = buildDataSet(trainX_dhw, trainY_dhw, 24)
testx_dhw, testy_dhw = buildDataSet(testX_dhw, testY_dhw, 24)
trainx_elec, trainy_elec = buildDataSet(trainX_elec, trainY_elec, 24)
testx_elec, testy_elec = buildDataSet(testX_elec, testY_elec, 24)
trainx_n_elec, trainy_n_elec = buildDataSet(trainX_n_elec, trainY_n_elec, 24)
testx_n_elec, testy_n_elec = buildDataSet(testX_n_elec, testY_n_elec, 24)

# %%
def seq2seq_model(input_shape):
    model_input = tf.keras.layers.Input(shape=input_shape)

    # for feature extracting
    conv1 = tf.keras.layers.Conv1D(64, 1, activation='swish')(model_input)
    pool1 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv1)
    conv2 = tf.keras.layers.Conv1D(32, 1, activation='swish')(pool1)
    pool2 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv2)
    conv3 = tf.keras.layers.Conv1D(128, 1, activation='swish')(pool2)
    pool3 = tf.keras.layers.MaxPool1D(pool_size=2, strides=1, padding='same')(conv3)

    # 인코더 - 디코더 선언
    encoder_lstm1 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh')
    encoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh')
    encoder_lstm3 = tf.keras.layers.LSTM(128, return_state=True, return_sequences=True, activation='tanh')

    decoder_lstm1 = tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh')
    decoder_lstm2 = tf.keras.layers.LSTM(32, return_sequences=True, activation='tanh')
    decoder_lstm3 = tf.keras.layers.LSTM(64, return_sequences=True, activation='tanh')

    # 인코더
    encoder_output_lstm1 = encoder_lstm1(pool3)
    encoder_output_lstm2 = encoder_lstm2(encoder_output_lstm1)
    encoder_output_lstm3, state_h, state_c = encoder_lstm3(encoder_output_lstm2)

    #디코더
    decoder_lstm1_output = decoder_lstm1(encoder_output_lstm3, initial_state=[state_h, state_c])
    decoder_lstm2_output = decoder_lstm2(decoder_lstm1_output)
    decoder_lstm3_output = decoder_lstm3(decoder_lstm2_output)

    flatten = tf.keras.layers.Flatten()(decoder_lstm3_output)
    model_output = tf.keras.layers.Dense(1, activation='swish')(flatten)
    
    model = tf.keras.models.Model(model_input, model_output)
    
    return model

# %%
model = seq2seq_model(input_shape=(24, 12))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 24, 12)]     0           []
#
#  conv1d (Conv1D)                (None, 24, 64)       832         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 24, 64)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 24, 32)       2080        ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 24, 32)      0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 24, 128)      4224        ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 24, 128)     0           ['conv1d_2[0][0]']
#
#  lstm (LSTM)                    (None, 24, 64)       49408       ['max_pooling1d_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 24, 32)       12416       ['lstm[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 24, 128),    82432       ['lstm_1[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_3 (LSTM)                  (None, 24, 128)      131584      ['lstm_2[0][0]',
#                                                                   'lstm_2[0][1]',
#                                                                   'lstm_2[0][2]']
#
#  lstm_4 (LSTM)                  (None, 24, 32)       20608       ['lstm_3[0][0]']
#
#  lstm_5 (LSTM)                  (None, 24, 64)       24832       ['lstm_4[0][0]']
#
#  flatten (Flatten)              (None, 1536)         0           ['lstm_5[0][0]']
#
#  dense (Dense)                  (None, 1)            1537        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 329,953
# Trainable params: 329,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델 컴파일
earlystopping = EarlyStopping(monitor='loss', patience=50)
checkpoint = ModelCheckpoint(moniter='loss',filepath='NELEC_source_sizedown.h5')
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adamax(learning_rate=3e-4,clipnorm=1.0), metrics=['mae'])
# 모델 요약 정보 출력
hist = model.fit(trainx_n_elec, trainy_n_elec, epochs=200, batch_size=64, callbacks=[earlystopping,checkpoint])
# Out:
# Epoch 1/200
# 52/52 [==============================] - 10s 26ms/step - loss: 4.2935 - mae: 4.2935
# Epoch 2/200
# 52/52 [==============================] - 1s 17ms/step - loss: 0.7279 - mae: 0.7279
# Epoch 3/200
# 52/52 [==============================] - 1s 14ms/step - loss: 0.7020 - mae: 0.7020
# Epoch 4/200
# 52/52 [==============================] - 1s 14ms/step - loss: 0.6819 - mae: 0.6819
# Epoch 5/200
# 52/52 [==============================] - 1s 14ms/step - loss: 0.6452 - mae: 0.6452
# Epoch 6/200
# 52/52 [==============================] - 1s 14ms/step - loss: 0.5790 - mae: 0.5790
# Epoch 7/200
# 52/52 [==============================] - 1s 17ms/step - loss: 0.5560 - mae: 0.5560
# Epoch 8/200
# 52/52 [==============================] - 1s 16ms/step - loss: 0.5191 - mae: 0.5191
# Epoch 9/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.4778 - mae: 0.4778
# Epoch 10/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.5154 - mae: 0.5154
# Epoch 11/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4583 - mae: 0.4583
# Epoch 12/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3703 - mae: 0.3703
# Epoch 13/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4246 - mae: 0.4246
# Epoch 14/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3546 - mae: 0.3546
# Epoch 15/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3456 - mae: 0.3456
# Epoch 16/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3487 - mae: 0.3487
# Epoch 17/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3222 - mae: 0.3222
# Epoch 18/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3216 - mae: 0.3216
# Epoch 19/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3671 - mae: 0.3671
# Epoch 20/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3051 - mae: 0.3051
# Epoch 21/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3337 - mae: 0.3337
# Epoch 22/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.4170 - mae: 0.4170
# Epoch 23/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3057 - mae: 0.3057
# Epoch 24/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3427 - mae: 0.3427
# Epoch 25/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.2804 - mae: 0.2804
# Epoch 26/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3144 - mae: 0.3144
# Epoch 27/200
# 52/52 [==============================] - 1s 13ms/step - loss: 0.3142 - mae: 0.3142
# Epoch 28/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3089 - mae: 0.3089
# Epoch 29/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.3089 - mae: 0.3089
# Epoch 30/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2802 - mae: 0.2802
# Epoch 31/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2428 - mae: 0.2428
# Epoch 32/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2365 - mae: 0.2365
# Epoch 33/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2898 - mae: 0.2898
# Epoch 34/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2059 - mae: 0.2059
# Epoch 35/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2364 - mae: 0.2364
# Epoch 36/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2297 - mae: 0.2297
# Epoch 37/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2641 - mae: 0.2641
# Epoch 38/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2464 - mae: 0.2464
# Epoch 39/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2079 - mae: 0.2079
# Epoch 40/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2125 - mae: 0.2125
# Epoch 41/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2471 - mae: 0.2471
# Epoch 42/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1975 - mae: 0.1975
# Epoch 43/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1989 - mae: 0.1989
# Epoch 44/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1936 - mae: 0.1936
# Epoch 45/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2337 - mae: 0.2337
# Epoch 46/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.2366 - mae: 0.2366
# Epoch 47/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2032 - mae: 0.2032
# Epoch 48/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.2145 - mae: 0.2145
# Epoch 49/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1738 - mae: 0.1738
# Epoch 50/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1773 - mae: 0.1773
# Epoch 51/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1742 - mae: 0.1742
# Epoch 52/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1839 - mae: 0.1839
# Epoch 53/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1748 - mae: 0.1748
# Epoch 54/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1566 - mae: 0.1566
# Epoch 55/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1696 - mae: 0.1696
# Epoch 56/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1766 - mae: 0.1766
# Epoch 57/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1639 - mae: 0.1639
# Epoch 58/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1669 - mae: 0.1669
# Epoch 59/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1677 - mae: 0.1677
# Epoch 60/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1744 - mae: 0.1744
# Epoch 61/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1866 - mae: 0.1866
# Epoch 62/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1846 - mae: 0.1846
# Epoch 63/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1440 - mae: 0.1440
# Epoch 64/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1548 - mae: 0.1548
# Epoch 65/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1642 - mae: 0.1642
# Epoch 66/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1903 - mae: 0.1903
# Epoch 67/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1882 - mae: 0.1882
# Epoch 68/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1827 - mae: 0.1827
# Epoch 69/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1619 - mae: 0.1619
# Epoch 70/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1449 - mae: 0.1449
# Epoch 71/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1566 - mae: 0.1566
# Epoch 72/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1405 - mae: 0.1405
# Epoch 73/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1429 - mae: 0.1429
# Epoch 74/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1367 - mae: 0.1367
# Epoch 75/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1356 - mae: 0.1356
# Epoch 76/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1353 - mae: 0.1353
# Epoch 77/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1746 - mae: 0.1746
# Epoch 78/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1696 - mae: 0.1696
# Epoch 79/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1676 - mae: 0.1676
# Epoch 80/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1492 - mae: 0.1492
# Epoch 81/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1401 - mae: 0.1401
# Epoch 82/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1260 - mae: 0.1260
# Epoch 83/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1254 - mae: 0.1254
# Epoch 84/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1480 - mae: 0.1480
# Epoch 85/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1578 - mae: 0.1578
# Epoch 86/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1543 - mae: 0.1543
# Epoch 87/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1200 - mae: 0.1200
# Epoch 88/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1197 - mae: 0.1197
# Epoch 89/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1229 - mae: 0.1229
# Epoch 90/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1234 - mae: 0.1234
# Epoch 91/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1178 - mae: 0.1178
# Epoch 92/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1086 - mae: 0.1086
# Epoch 93/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1199 - mae: 0.1199
# Epoch 94/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1280 - mae: 0.1280
# Epoch 95/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1330 - mae: 0.1330
# Epoch 96/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1211 - mae: 0.1211
# Epoch 97/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1096 - mae: 0.1096
# Epoch 98/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1115 - mae: 0.1115
# Epoch 99/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1132 - mae: 0.1132
# Epoch 100/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1153 - mae: 0.1153
# Epoch 101/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1330 - mae: 0.1330
# Epoch 102/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1179 - mae: 0.1179
# Epoch 103/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1097 - mae: 0.1097
# Epoch 104/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1210 - mae: 0.1210
# Epoch 105/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1188 - mae: 0.1188
# Epoch 106/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1135 - mae: 0.1135
# Epoch 107/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1189 - mae: 0.1189
# Epoch 108/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1170 - mae: 0.1170
# Epoch 109/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1211 - mae: 0.1211
# Epoch 110/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1123 - mae: 0.1123
# Epoch 111/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1061 - mae: 0.1061
# Epoch 112/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1207 - mae: 0.1207
# Epoch 113/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1310 - mae: 0.1310
# Epoch 114/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1453 - mae: 0.1453
# Epoch 115/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1356 - mae: 0.1356
# Epoch 116/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1120 - mae: 0.1120
# Epoch 117/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1089 - mae: 0.1089
# Epoch 118/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1147 - mae: 0.1147
# Epoch 119/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1179 - mae: 0.1179
# Epoch 120/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1196 - mae: 0.1196
# Epoch 121/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1164 - mae: 0.1164
# Epoch 122/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1071 - mae: 0.1071
# Epoch 123/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1024 - mae: 0.1024
# Epoch 124/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1055 - mae: 0.1055
# Epoch 125/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1080 - mae: 0.1080
# Epoch 126/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1080 - mae: 0.1080
# Epoch 127/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1100 - mae: 0.1100
# Epoch 128/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1040 - mae: 0.1040
# Epoch 129/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1020 - mae: 0.1020
# Epoch 130/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1087 - mae: 0.1087
# Epoch 131/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1291 - mae: 0.1291
# Epoch 132/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1183 - mae: 0.1183
# Epoch 133/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1072 - mae: 0.1072
# Epoch 134/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1032 - mae: 0.1032
# Epoch 135/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1297 - mae: 0.1297
# Epoch 136/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1033 - mae: 0.1033
# Epoch 137/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0990 - mae: 0.0990
# Epoch 138/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1036 - mae: 0.1036
# Epoch 139/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0968 - mae: 0.0968
# Epoch 140/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1033 - mae: 0.1033
# Epoch 141/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1077 - mae: 0.1077
# Epoch 142/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0991 - mae: 0.0991
# Epoch 143/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1046 - mae: 0.1046
# Epoch 144/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1026 - mae: 0.1026
# Epoch 145/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1104 - mae: 0.1104
# Epoch 146/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1042 - mae: 0.1042
# Epoch 147/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0992 - mae: 0.0992
# Epoch 148/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0988 - mae: 0.0988
# Epoch 149/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1036 - mae: 0.1036
# Epoch 150/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0993 - mae: 0.0993
# Epoch 151/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0973 - mae: 0.0973
# Epoch 152/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1051 - mae: 0.1051
# Epoch 153/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1108 - mae: 0.1108
# Epoch 154/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1018 - mae: 0.1018
# Epoch 155/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0998 - mae: 0.0998
# Epoch 156/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1011 - mae: 0.1011
# Epoch 157/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0954 - mae: 0.0954
# Epoch 158/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0961 - mae: 0.0961
# Epoch 159/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1036 - mae: 0.1036
# Epoch 160/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0986 - mae: 0.0986
# Epoch 161/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0987 - mae: 0.0987
# Epoch 162/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.1042 - mae: 0.1042
# Epoch 163/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0951 - mae: 0.0951
# Epoch 164/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0970 - mae: 0.0970
# Epoch 165/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0949 - mae: 0.0949
# Epoch 166/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0971 - mae: 0.0971
# Epoch 167/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0964 - mae: 0.0964
# Epoch 168/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0936 - mae: 0.0936
# Epoch 169/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0982 - mae: 0.0982
# Epoch 170/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0971 - mae: 0.0971
# Epoch 171/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0934 - mae: 0.0934
# Epoch 172/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1011 - mae: 0.1011
# Epoch 173/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0933 - mae: 0.0933
# Epoch 174/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0903 - mae: 0.0903
# Epoch 175/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0896 - mae: 0.0896
# Epoch 176/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0960 - mae: 0.0960
# Epoch 177/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0969 - mae: 0.0969
# Epoch 178/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0986 - mae: 0.0986
# Epoch 179/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1035 - mae: 0.1035
# Epoch 180/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1016 - mae: 0.1016
# Epoch 181/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0930 - mae: 0.0930
# Epoch 182/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0890 - mae: 0.0890
# Epoch 183/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1219 - mae: 0.1219
# Epoch 184/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0981 - mae: 0.0981
# Epoch 185/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0927 - mae: 0.0927
# Epoch 186/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0950 - mae: 0.0950
# Epoch 187/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0934 - mae: 0.0934
# Epoch 188/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1163 - mae: 0.1163
# Epoch 189/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.1004 - mae: 0.1004
# Epoch 190/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0991 - mae: 0.0991
# Epoch 191/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0916 - mae: 0.0916
# Epoch 192/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0931 - mae: 0.0931
# Epoch 193/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0859 - mae: 0.0859
# Epoch 194/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0891 - mae: 0.0891
# Epoch 195/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0924 - mae: 0.0924
# Epoch 196/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0944 - mae: 0.0944
# Epoch 197/200
# 52/52 [==============================] - 1s 11ms/step - loss: 0.0903 - mae: 0.0903
# Epoch 198/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0949 - mae: 0.0949
# Epoch 199/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0953 - mae: 0.0953
# Epoch 200/200
# 52/52 [==============================] - 1s 12ms/step - loss: 0.0897 - mae: 0.0897

# %%
model = load_model('NELEC_source_sizedown.h5')
pred = model.predict(testx_n_elec)
pred = np.reshape(pred,(-1,1))

real = np.array(testy_n_elec)
# Out:
# 44/44 [==============================] - 1s 5ms/step

# %%
from sklearn.metrics import mean_absolute_error
print('MAE : ', round(mean_absolute_error(real, pred),4)) 

from sklearn.metrics import mean_squared_error
print('MSE : ', round(mean_squared_error(real, pred),4))

from sklearn.metrics import r2_score
print('R2 : ', round(r2_score(real, pred),4))
# Out:
# MAE :  0.1166
# MSE :  0.025
# R2 :  0.9296

# %%
# plt.figure(figsize=(40,10))
# #plt.ylabel('DHW consumption[LighGBM+FCN]',size=20)
# plt.plot(real, color='red', label='True')
# plt.plot(pred, color='blue',label='False')
# plt.legend()
# plt.show()

# %%
# trainSize = int(len(elec_ori) * 0.7)
# elec_ori['date'] = pd.to_datetime(elec_ori.iloc[:,:4])
# test_date = elec_ori[['date']].iloc[trainSize:]
# test_date = test_date.iloc[:-3]
# test_date

# %%
plt.figure(figsize=(8,5))
plt.ylabel('National ELEC consumption')
plt.plot(real, color='orange',label='True')
plt.plot(pred, color='blue',label='Pred')
plt.legend()
plt.show()
